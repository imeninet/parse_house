# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import requests
url = 'https://наш.дом.рф/сервисы/каталог-новостроек/список-объектов/список?page=0&limit=130&subject=33' 
r = requests.get(url).text
soup = BeautifulSoup(r, "html.parser")

# %%
new = soup.findAll('a') 
print(new)
# Out:
# [<a class="styles__LogoMinstroy-sc-1cja9xq-4 cbPfdo" href="http://www.minstroyrf.ru/" target="_blank"></a>, <a class="styles__LogoDomRfContainer-sc-1cja9xq-6 ElFNA" href="/"><div class="styles__LogoDomRf-sc-1cja9xq-7 llHTdj"></div><div class="styles__LogoText-sc-1cja9xq-8 hCooUB">единая
# информационная
# система жилищного
# строительства</div></a>, <a class="styles__LogoMinstroy-sc-1ddwc6h-6 kECPhx" href="http://www.minstroyrf.ru/" target="_blank"></a>, <a class="styles__LogoDomRf-sc-1ddwc6h-8 jwnfpq" href="/"></a>, <a class="ContactCenter__Phone-xsecuv-2 jZhtnU" href="tel:88007007214">8 (800) 7007-214</a>, <a class="ContactCenter__Phone-xsecuv-2 jZhtnU" href="mailto:nash@domrf.ru">nash@domrf.ru</a>, <a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444"><div class="styles__Row-sc-13ibavg-0 styles__Content-gwedej-1 bKgKXU"><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_status"><div class="styles__Container-nadbfs-1 jusJtu"><div class="styles__Status-nadbfs-0 gWWIBl"></div></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN" style="width:220px"><div class="styles__Container-cx1nz2-3 fogXBx"><a><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Primary-cx1nz2-1 iYOEEb">23444</span></div><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Secondary-cx1nz2-2 faCSkM">33-000214</span></div></a></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal"><a class="styles__Address-j3mki0-0 kuWfkU" href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444">г Покров, Улица III Интернационала, д. 3</a></div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal" style="overflow:hidden"><div class="styles__Container-b0i2cq-3 kNQIYT"><a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%B5%D0%B4%D0%B8%D0%BD%D1%8B%D0%B9-%D1%80%D0%B5%D0%B5%D1%81%D1%82%D1%80-%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA%D0%BE%D0%B2/%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA/2826"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk">ООО «АС-ИНВЕСТ»</span></span></a><a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%B5%D0%B4%D0%B8%D0%BD%D1%8B%D0%B9-%D1%80%D0%B5%D0%B5%D1%81%D1%82%D1%80-%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA%D0%BE%D0%B2/%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B0-%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B9/8152854001"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk">АС-ИНВЕСТ</span></span></a></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small">3</div><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small">33</div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal" style="justify-content:flex-end">1 646</div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal" style="justify-content:flex-end">II кв. 2021</div></div></a>, <a><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Primary-cx1nz2-1 iYOEEb">23444</span></div><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Secondary-cx1nz2-2 faCSkM">33-000214</span></div></a>, <a class="styles__Address-j3mki0-0 kuWfkU" href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/2344 ...

# %%
new_news = []
for i in range(len(new)):
    if new[i].find('span', class_='styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Primary-cx1nz2-1 iYOEEb') is not None:
div class="styles__Title-sc-1rfaqsr-4 jvKrMx"><div class="styles__SortedDirection-sc-1rfaqsr-1 eUfWSQ"></div><div class="styles__Content-sc-1rfaqsr-0 bSLAYy">Адрес дома</div></div></div></div><div class="styles__HeaderCell-sc-1rfaqsr-2 hbzIVx BuildersTable_normal" style="overflow:hidden"><div class="styles__Wrapper-sc-1rfaqsr-3 kUbqQN"><div class="styles__Title-sc-1rfaqsr-4 jvKrMx"><div class="styles__SortedDirection-sc-1rfaqsr-1 dIwyNL"></div><div class="styles__Content-sc-1rfaqsr-0 bSLAYy">Застройщик / ГК</div></div></div></div><div class="styles__HeaderCell-sc-1rfaqsr-2 XHLfi Newbuildings_small"><div class="styles__Wrapper-sc-1rfaqsr-3 kUbqQN"><div class="styles__Title-sc-1rfaqsr-4 jvKrMx"><div class="styles__SortedDirection-sc-1rfaqsr-1 eUfWSQ"></div><div class="styles__Content-sc-1rfaqsr-0 bSLAYy">Этажей</div></div></div></div><div class="styles__HeaderCell-sc-1rfaqsr-2 XHLfi Newbuildings_small"><div class="styles__Wrapper-sc-1rfaqsr-3 kUbqQN"><div class="styles__Title-sc-1rfaqsr-4 jvKrMx"><div class="styles__SortedDirection-sc-1rfaqsr-1 eUfWSQ"></div><div class="styles__Content-sc-1rfaqsr-0 bSLAYy">Квартир</div></div></div></div><div class="styles__HeaderCell-sc-1rfaqsr-2 XHLfi BuildersTable_normal" style="justify-content:flex-end"><div class="styles__Wrapper-sc-1rfaqsr-3 kUbqQN"><div class="styles__Title-sc-1rfaqsr-4 jvKrMx"><div class="styles__SortedDirection-sc-1rfaqsr-1 eUfWSQ"></div><div class="styles__Content-sc-1rfaqsr-0 bSLAYy">Площадь, м²</div></div></div></div><div class="styles__HeaderCell-sc-1rfaqsr-2 XHLfi BuildersTable_normal" style="justify-content:flex-end"><div class="styles__Wrapper-sc-1rfaqsr-3 kUbqQN"><div class="styles__Title-sc-1rfaqsr-4 jvKrMx"><div class="styles__SortedDirection-sc-1rfaqsr-1 eUfWSQ"></div><div class="styles__Content-sc-1rfaqsr-0 bSLAYy">Ввод в эксплуатацию</div></div></div></div></div><div><a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444"><div class="styles__Row-sc-13ibavg-0 styles__Content-gwedej-1 bKgKXU"><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_status"><div class="styles__Container-nadbfs-1 jusJtu"><div class="styles__Status-nadbfs-0 gWWIBl"></div></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN" style="width:220px"><div class="styles__Container-cx1nz2-3 fogXBx"><a><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Primary-cx1nz2-1 iYOEEb">23444</span></div><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Secondary-cx1nz2-2 faCSkM">33-000214</span></div></a></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal"><a class="styles__Address-j3mki0-0 kuWfkU" href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444">г Покров, Улица III Интернационала, д. 3</a></div><div class="styles__Cell-sc-7809tj-0 ibavEN  ...

# %%
movie_desc = soup1.find('div', {'class': 'styles__Table-sc-17it3za-0 bPlHag'}).find('a').text
print(movie_desc)
# Out:
# 2344433-000214г Покров, Улица III Интернационала, д. 3ООО «АС-ИНВЕСТ»АС-ИНВЕСТ3331 646II кв. 2021

# %%
id_house = soup1.find('div', {'class': 'styles__Row-cx1nz2-4 wMwPR'}).text
print(id_house)
# Out:
# 23444

# %%
adress = soup1.find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal'}).text
print(adress)
# Out:
# г Покров, Улица III Интернационала, д. 3

# %%
link1 = soup1.find('div', {'class': 'styles__Table-sc-17it3za-0 bPlHag'}).find('a').get('href')
print(link1)
# Out:
# https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444

# %%
link = soup1.find('div', {'class': 'styles__Table-sc-17it3za-0 bPlHag'}).find('div', attrs=False).find('a', recursive=False).get('href')
print(link)
# Out:
# https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444

# %%
print(new)
# Out:
# [<a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23444"><div class="styles__Row-sc-13ibavg-0 styles__Content-gwedej-1 bKgKXU"><div
cq-0 styles__Secondary-b0i2cq-2 hAIbPk">АС-ИНВЕСТ</span></span></a></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small">3</div><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small">33</div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal" style="justify-content:flex-end">1 646</div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal" style="justify-content:flex-end">II кв. 2021</div></div></a>, <a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%BA%D0%B0%D1%82%D0%B0%D0%BB%D0%BE%D0%B3-%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BA/%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82/23445"><div class="styles__Row-sc-13ibavg-0 styles__Content-gwedej-1 bKgKXU"><div class="styles__Cell-sc-7809tj-0 ibavEN Newbuildings_status"><div class="styles__Container-nadbfs-1 jusJtu"><div class="styles__Status-nadbfs-0 gWWIBl"></div></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN" style="width:220px"><div class="styles__Container-cx1nz2-3 fogXBx"><a><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Primary-cx1nz2-1 iYOEEb">23445</span></div><div class="styles__Row-cx1nz2-4 wMwPR"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-cx1nz2-0 styles__Secondary-cx1nz2-2 faCSkM">33-000214</span></div></a></div></div><div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTa ...

# %%
devel = soup1.find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk'}).text
print(devel)
# Out:
# ООО «АС-ИНВЕСТ»

# %%
dev_group = soup1.find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk'}).text
print(dev_group)
# Out:
# АС-ИНВЕСТ

# %%
floor = soup1.find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small'}).text
print(floor)
# Out:
# 3

# %%
problem_house = soup1.find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal', 'style': True})
print(problem_house)
# Out:
# <div class="styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal" style="overflow:hidden"><div class="styles__Container-b0i2cq-3 kNQIYT"><a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%B5%D0%B4%D0%B8%D0%BD%D1%8B%D0%B9-%D1%80%D0%B5%D0%B5%D1%81%D1%82%D1%80-%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA%D0%BE%D0%B2/%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA/2826"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk">ООО «АС-ИНВЕСТ»</span></span></a><a href="https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/%D0%B5%D0%B4%D0%B8%D0%BD%D1%8B%D0%B9-%D1%80%D0%B5%D0%B5%D1%81%D1%82%D1%80-%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D1%89%D0%B8%D0%BA%D0%BE%D0%B2/%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B0-%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B9/8152854001"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk"><span class="styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk">АС-ИНВЕСТ</span></span></a></div></div>

# %%
import pandas as pd

# %%
new = soup1.find('div', class_="styles__Blur-gomtho-2 bufOEh").find('div', class_=False).findAll('a', recursive=False)
# new = soup1.find_all('a', recursive=False)
new_news = []
for i in range(len(new)):
  if new[i].find('div', class_= 'styles__Row-cx1nz2-4 wMwPR') is not None:
    id_house = new[i].find('div', class_= 'styles__Row-cx1nz2-4 wMwPR').text
  if new[i].find('div', class_= 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal') is not None:
    adress = new[i].find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal'}).text
  if new[i].find('div', class_= 'styles__Container-b0i2cq-3 kNQIYT') is not None:
    devel = new[i].find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk'}).text   
  if new[i].find('div', class_= 'styles__Container-b0i2cq-3 kNQIYT') is not None:
    try:
      dev_group = new[i].find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk'}).text
    except AttributeError:
      dev_group = 'NonGroup'
  if new[i].find('div', class_= 'styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small') is not None:
    floors = new[i].find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small'}).text
  if new[i].find('div', class_= 'styles__Table-sc-17it3za-0 bPlHag') is not None:
    link = new[i].find('a').get('href')
  if new[i].find('div', class_= 'styles__Status-nadbfs-0 jUTMVJ') is not None:
    problem = 'Внимание! Проблемный!'
  elif new[i].find('div', class_= 'styles__Status-nadbfs-0 gWWIBl') is not None:
    problem = 'Все ОК!'
  
  tables = {
    'id_house': id_house,
    'adress': adress,
    'developer': devel,
    'dev_groups': dev_group,
    'floors': floors,
    'problem': problem,
    'link': link    
    }
  new_news.append(tables)

data_df = pd.DataFrame(new_news)
data_df.head()

#id_house = soup1.find('div', {'class': 'styles__Row-cx1nz2-4 wMwPR'}).text
# adress = soup1.find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal'}).text
# devel = soup1.find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk'}).text
# dev_group = soup1.find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk'}).text
# floors = soup1.find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small'}).text
# link = soup1.find('div', {'class': 'styles__Table-sc-17it3za-0 bPlHag'}).find('a').get('href')

# tables = {
#   'id_house': id_house,
#   'adress': adress,
#   'devel': devel,
#   'dev_group': dev_group,
#   'floors': floors,
#   'link': link,
#   }
    
# print(tables)
# Out:
#   id_house  ...                                               link
# 0    23444  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 1    23445  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 2    23443  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 3    22497  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 4    22496  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
#
# [5 rows x 7 columns]

# %%
dev_group = soup1.find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk'}).text
print(dev_group)
# Out:
# АС-ИНВЕСТ

# %%
data_df.tail()
# Out:
#     id_house  ...                                               link
# 111    30637  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 112    30627  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 113    30636  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 114    30630  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
# 115    33677  ...  https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D...
#
# [5 rows x 7 columns]

# %%
data_df.to_excel("parse_house.xlsx")
from google.colab import files
uploaded = files.upload()
uploaded['parse_house.xlsx']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a932fa8d0f6> in <module>()
# ----> 1 data_df.to_excel("parse_house.xlsx")
#       2 from google.colab import files
#       3 uploaded = files.upload()
#       4 uploaded['parse_house.xlsx']
#
# NameError: name 'data_df' is not defined

# %%
for i in range(115):
  if data_df['problem'][i] == 'Внимание! Проблемный!':
    print(data_df[id_house][i])
# data_df['problem']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '33677'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-276-797327e4b74c> in <module>()
#       1 for i in range(115):
#       2   if data_df['problem'][i] == 'Внимание! Проблемный!':
# ----> 3     print(data_df[id_house][i])
#       4 # data_df['problem']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '33677'

# %%
one_page['problem'].describe()
# Out:
# count         100
# unique          1
# top       Все ОК!
# freq          100
# Name: problem, dtype: object

# %%
url = 'https://наш.дом.рф/сервисы/каталог-новостроек/список-объектов/список?subject=33&page=1&limit=100' 
r = requests.get(url).text
soup2 = BeautifulSoup(r, "html.parser")
z = soup2.find('div', id=False)
print(z)
# Out:
# <div class="styles__MenuWrapper-sc-1cja9xq-0 lbCTd"><div class="styles__SubMenuWrapper-sc-1cja9xq-1 iMSNWZ"><div class="styles__MenuContainer-sc-1cja9xq-2 hrdJVD"><div class="styles__LogoContainer-sc-1cja9xq-9 iKflPT"><a class="styles__LogoMinstroy-sc-1cja9xq-4 cbPfdo" href="http://www.minstroyrf.ru/" target="_blank"></a><div class="styles__LogoDivider-sc-1cja9xq-5 jbWpUR"></div><a class="styles__LogoDomRfContainer-sc-1cja9xq-6 ElFNA" href="/"><div class="styles__LogoDomRf-sc-1cja9xq-7 llHTdj"></div><div class="styles__LogoText-sc-1cja9xq-8 hCooUB">единая
# информационная
# система жилищного
# строительства</div></a></div><div class="styles__LeftContainer-sc-1cja9xq-3 kJRnkS"><div class="styles__LinkContainer-sc-1cja9xq-10 jVdUBa"><span></span></div><div class="styles__Icons-sc-1cja9xq-11 vuszp"><div class="styles__SearchIcon-sc-1cja9xq-13 eaoJnP"></div><div class="styles__BurgerIcon-sc-1cja9xq-12 cixRmT"></div></div></div></div><div class="styles__Wrapper-bkf3fl-0 kvwLQT"><div class="styles__Container-bkf3fl-1 hwUcGF"></div></div></div><div class="styles__MenuContainer-sc-1ddwc6h-0 eGhgKS"><div class="styles__Header-sc-1ddwc6h-1 cINAul"><div class="styles__LogoBlock-sc-1ddwc6h-5 fmjNzo"><a class="styles__LogoMinstroy-sc-1ddwc6h-6 kECPhx" href="http://www.minstroyrf.ru/" target="_blank"></a><div class="styles__LogoDivider-sc-1ddwc6h-7 lavDEx"></div><a class="styles__LogoDomRf-sc-1ddwc6h-8 jwnfpq" href="/"></a></div><div class="styles__Icons-sc-1ddwc6h-9 jxXDtZ"><div class="styles__Search-sc-1ddwc6h-10 bnERCQ"></div><div class="styles__Close-sc-1ddwc6h-11 bwZOIz"></div></div></div><div class="styles__BackButton-sc-1ddwc6h-2 bSnlme"><div class="styles__Arrow-sc-1ddwc6h-12 ggVovp"></div><p class="styles__BackText-sc-1ddwc6h-13 iTcnTL">Назад</p></div><div class="styles__Content-sc-1ddwc6h-3 leLrNG"></div><div class="styles__ContactCenterWrapper-sc-1ddwc6h-4 cYDfaU"><div class="ContactCenter__Contacts-xsecuv-0 bZSizB"><p class="ContactCenter__Text-xsecuv-1 geuFwx">Контактный центр</p><a class="ContactCenter__Phone-xsecuv-2 jZhtnU" href="tel:88007007214">8 (800) 7007-214</a><a class="ContactCenter__Phone-xsecuv-2 jZhtnU" href="mailto:nash@domrf.ru">nash@domrf.ru</a></div></div></div></div>

# %%
new = soup2.find('div', class_=False).find_all('a', recursive=False)
# new = soup1.find_all('a', recursive=False)
new_news = []
for i in range(len(new)):
  if new[i].find('div', class_= 'styles__Row-cx1nz2-4 wMwPR') is not None:
    id_house = new[i].find('div', class_= 'styles__Row-cx1nz2-4 wMwPR').text
  if new[i].find('div', class_= 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal') is not None:
    adress = new[i].find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN BuildersTable_normal'}).text
  if new[i].find('div', class_= 'styles__Container-b0i2cq-3 kNQIYT') is not None:
    devel = new[i].find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Primary-b0i2cq-1 cHOchk'}).text   
  if new[i].find('div', class_= 'styles__Container-b0i2cq-3 kNQIYT') is not None:
    try:
      dev_group = new[i].find('div', {'class': 'styles__Container-b0i2cq-3 kNQIYT'}).find('span', {'class': 'styles__Ellipsis-sc-1fw79ul-0 cDcbYl styles__Child-b0i2cq-0 styles__Secondary-b0i2cq-2 hAIbPk'}).text
    except AttributeError:
      dev_group = 'NonGroup'
  if new[i].find('div', class_= 'styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small') is not None:
    floors = new[i].find('div', {'class': 'styles__Cell-sc-7809tj-0 ibavEN Newbuildings_small'}).text
  if new[i].find('div', class_= 'styles__Table-sc-17it3za-0 bPlHag') is not None:
    link = new[i].find('div', {'class': 'styles__Table-sc-17it3za-0 bPlHag'}).find('a').get('href')
  if new[i].find('div', class_= 'styles__Status-nadbfs-0 jUTMVJ') is not None:
    problem = 'Внимание! Проблемный!'
  elif new[i].find('div', class_= 'styles__Status-nadbfs-0 gWWIBl') is not None:
    problem = 'Все ОК!'
  
  tables = {
    'id_house': id_house,
    'adress': adress,
    'developer': devel,
    'dev_groups': dev_group,
    'floors': floors,
    'problem': problem,
    'link': link    
    }
  new_news.append(tables)

data_df = pd.DataFrame(new_news)
data_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-fd81ba8712aa> in <module>()
#       2 # new = soup1.find_all('a', recursive=False)
#       3 new_news = []
# ----> 4 for i in range(len(new)):
#       5   if new[i].find('div', class_= 'styles__Row-cx1nz2-4 wMwPR') is not None:
#       6     id_house = new[i].find('div', class_= 'styles__Row-cx1nz2-4 wMwPR').text
#
# TypeError: object of type 'NoneType' has no len()
